# %% [markdown]
# # AI Final Project

# %% [markdown]
# Made By: Harsh Tiwari
#
# Done Under: Niel Bruce

# %% [markdown]
# This is final project for CIS*6020 which is a **Beverage Recommendation System**. This project will help in deciding what would they have depending on  the alcohol, or on what others are drinking.  This is a Collaborative filtering based approach in which you will get recommended what others will drink in a bar or club or cafes.

# %% [markdown]
# # Importing Relevant Libraries and Dataset

# %% [markdown]
# Importing relevant Libraries for our project

# %%
import numpy as np # for mathematical Calculations
import pandas as pd # for data analysis and data Manipulations
import matplotlib.pyplot as plt # for Data visualizations
import seaborn as sns # for advanced plotting
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from kerastuner.tuners import RandomSearch
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping
import json
import random

# %% [markdown]
# Importing the dataset. Our dataset is in the form of a raw csv file and stored in a GitHub Repository.

# %%
url = "https://raw.githubusercontent.com/HarshTiwari1710/Sobershot/refs/heads/main/mr-boston-flattened.csv"

# %%
drinks_df = pd.read_csv(url)

# %%
drinks_df
# Out:
#                      name               category measurement-1  \
# 0                 Gauguin      Cocktail Classics          2 oz
# 1         Fort Lauderdale      Cocktail Classics      1 1/2 oz
# 2               Apple Pie  Cordials and Liqueurs          3 oz
# 3    Cuban Cocktail No. 1      Cocktail Classics        1/2 oz
# 4             Cool Carlos      Cocktail Classics      1 1/2 oz
# ..                    ...                    ...           ...
# 985  Wallis Blue Cocktail                    Gin             1
# 986    Minnehaha Cocktail      Cocktail Classics        1/4 oz
# 987      Wallick Cocktail                    Gin      1 1/2 oz
# 988   Waikiki Beachcomber                    Gin        3/4 oz
# 989        Vow Of Silence                    Gin      1 1/2 oz
#
#                     ingredient-1 measurement-2          ingredient-2  \
# 0                      Light Rum          1 oz   Passion Fruit Syrup
# 1                      Light Rum        1/2 oz        Sweet Vermouth
# 2                 Apple schnapps          1 oz     Cinnamon schnapps
# 3                Juice of a Lime        1/2 oz        Powdered Sugar
# 4                       Dark rum          2 oz       Cranberry Juice
# ..                           ...           ...                   ...
# 985  Lime wedge, superfine sugar          1 oz                   Gin
# 986              Juice of Orange        1/2 oz          Dry Vermouth
# 987                          Gin      1 1/2 oz          Dry Vermouth
# 988                          Gin        3/4 oz            Triple Sec
# 989                          Gin        3/4 oz      Grapefruit Juice
#
#     measurement-3       ingredient-3 measurement-4             ingredient-4  \
# 0            1 oz        Lemon Juice          1 oz               Lime Juice
# 1          1/4 oz    Juice of Orange        1/4 oz          Juice of a Lime
# 2             NaN        Apple slice           NaN                      NaN
# 3            2 oz          Light Rum           NaN                      NaN
# 4            2 oz    Pineapple Juice          1 oz           Orange curacao
# ..            ...                ...           ...                      ...
# 985          1 oz         Triple Sec          1 oz         Fresh Lime Juice
# 986        1/2 oz     Sweet Vermouth          1 oz   Old Mr. Boston Dry Gin
# 987          1 oz         Triple Sec           NaN                      NaN
# 988        1/2 oz    Pineapple Juice           NaN                      NaN
# 989        1/2 oz   Fresh Lime Juice        1/2 oz        Yellow Chartreuse
#
#     measurement-5 ingredient-5 measurement-6   ingredient-6  \
# 0             NaN          NaN           NaN            NaN
# 1             NaN          NaN           NaN            NaN
# 2             NaN          NaN           NaN            NaN
# 3             NaN          NaN           NaN            NaN
# 4            1 oz     Sour Mix           NaN            NaN
# ..            ...          ...           ...            ...
# 985           NaN          NaN           NaN            NaN
# 986           NaN          NaN           NaN            NaN
# 987           NaN          NaN           NaN            NaN
# 988           NaN          NaN           NaN            NaN
# 989        1/4 oz        Amaro        1/4 oz   Simple Syrup
#
#                                           instructions                glass  \
# 0    Combine ingredients with a cup of crushed ice ...  Old-Fashioned Glass
# 1    Shake with ice and strain into old-fashioned g...  Old-Fashioned Glass
# 2    Pour into ice-filled old-fashioned glass. Garn...  Old-Fashioned Glass
# 3      Shake with ice and  strain into cocktail glass.       Cocktail Glass
# 4    Mix all ingredients except curacao with ice, s...        Collins Glass
# ..                                                 ...                  ...
# 985  Rim old-fashioned glass with lime and sugar. F...  Old-Fashioned Glass
# 986  Shake well with cracked ice and strain into 4 ...       Cocktail Glass
# 987  Stir with ice and strain into chilled cocktail...       Cocktail Glass
# 988  Shake with ice and strain into chilled cocktai...       Cocktail Glass
# 989  Shake with ice and strain into chilled cocktai...       Cocktail Glass
#
#            glass-size                                              Image
# 0       6 to 8 ounces  ......
# 1       6 to 8 ounces  ......
# 2       6 to 8 ounces  ......
# 3    6 or more ounces  ......
# 4     14 to 16 ounces  ......
# ..                ...                                                ...
# 985     6 to 8 ounces  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 986  6 or more ounces  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 987  6 or more ounces  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 988  6 or more ounces  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 989  6 or more ounces  https://encrypted-tbn0.gstatic.com/images?q=tb...
#
# [990 rows x 18 columns]

# %% [markdown]
# # Data Exploration and EDA

# %% [markdown]
# Checking the count of null values in each column

# %%
drinks_df.isnull().sum()
# Out:
# name               0
# category           0
# measurement-1     10
# ingredient-1       1
# measurement-2     35
# ingredient-2       3
# measurement-3    143
# ingredient-3      96
# measurement-4    390
# ingredient-4     406
# measurement-5    683
# ingredient-5     669
# measurement-6    919
# ingredient-6     831
# instructions       0
# glass              5
# glass-size        11
# Image              0
# dtype: int64

# %% [markdown]
# Using describe, checking count, unique, top and frequency of values in the dataset.

# %%
drinks_df.describe()
# Out:
#            name           category measurement-1 ingredient-1 measurement-2  \
# count       990                990           980          989           955
# unique      990                 11            33          237            19
# top     Gauguin  Cocktail Classics      1 1/2 oz        Vodka          1 oz
# freq          1                468           289           95           291
#
#          ingredient-2 measurement-3        ingredient-3 measurement-4  \
# count             987           847                 894           600
# unique            256            22                 227            47
# top      Dry Vermouth        1/2 oz   Fresh lemon juice          1 oz
# freq               63           267                  57           195
#
#               ingredient-4 measurement-5        ingredient-5 measurement-6  \
# count                  584           307                 321            71
# unique                 173            44                 144            12
# top      Fresh lemon juice          1 oz   Angostura Bitters          1 oz
# freq                    33           101                  24            32
#
#         ingredient-6                                    instructions  \
# count            159                                             990
# unique           117                                             580
# top      Lemon twist  Shake with ice and strain into cocktail glass.
# freq               7                                             115
#
#                  glass        glass-size  \
# count              985               979
# unique              20                16
# top     Cocktail Glass  6 or more ounces
# freq               542               542
#
#                                                     Image
# count                                                 990
# unique                                                795
# top     ......
# freq                                                   76

# %%
drinks_df.columns
# Out:
# Index(['name', 'category', 'measurement-1', 'ingredient-1', 'measurement-2',
#        'ingredient-2', 'measurement-3', 'ingredient-3', 'measurement-4',
#        'ingredient-4', 'measurement-5', 'ingredient-5', 'measurement-6',
#        'ingredient-6', 'instructions', 'glass', 'glass-size', 'Image'],
#       dtype='object')

# %% [markdown]
# Plotting a graph for missing values in the dataset

# %%
def plot_missing_values_bar(drinks_df, figsize=(12, 6)):
    # Calculate missing values percentage
    missing_percentages = drinks_df.isnull().mean() * 100
    missing_percentages = missing_percentages[missing_percentages > 0].sort_values(ascending=False)
    
    # Create the plot with a professional style
    plt.figure(figsize=figsize)
    
    # Use seaborn for a more polished look
    sns.set_style("whitegrid")
    
    # Create bar plot with custom color palette
    ax = sns.barplot(
        x=missing_percentages.index, 
        y=missing_percentages.values, 
        palette='viridis'
    )
    
    # Customize the plot
    plt.title('Missing Values by Column', fontsize=16, fontweight='bold')
    plt.xlabel('Columns', fontsize=12)
    plt.ylabel('Percentage of Missing Values (%)', fontsize=12)
    plt.xticks(rotation=45, ha='right')
    
    # Add value labels on top of each bar
    for i, v in enumerate(missing_percentages.values):
        ax.text(
            i, 
            v + 0.5, 
            f'{v:.2f}%', 
            ha='center', 
            va='bottom',
            fontweight='bold'
        )
    
    # Adjust layout
    plt.tight_layout()
    
    # Show the plot
    plt.show()
    
    # Print summary of missing values
    missing_summary = pd.DataFrame({
        'Total Missing': drinks_df.isnull().sum(),
        'Percent Missing (%)': drinks_df.isnull().mean() * 100
    })
    print("\nMissing Values Summary:")
    print(missing_summary[missing_summary['Total Missing'] > 0].round(2))

# Example usage
plot_missing_values_bar(drinks_df)
# Out:
# Missing Values Summary:
#                Total Missing  Percent Missing (%)
# measurement-1             10                 1.01
# ingredient-1               1                 0.10
# measurement-2             35                 3.54
# ingredient-2               3                 0.30
# measurement-3            143                14.44
# ingredient-3              96                 9.70
# measurement-4            390                39.39
# ingredient-4             406                41.01
# measurement-5            683                68.99
# ingredient-5             669                67.58
# measurement-6            919                92.83
# ingredient-6             831                83.94
# glass                      5                 0.51
# glass-size                11                 1.11

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# Combining all the ingredients in a dictionary so as when we will create UI and fetch it in the frontend and show this it will be easily accessible

# %%
def combine_ingredients_to_dict(row, num_pairs=6):
    ingredients_dict = {}
    for i in range(1, num_pairs + 1):
        ingredient_col = f'ingredient-{i}'
        measurement_col = f'measurement-{i}'
        if ingredient_col in row:
            ingredient = row[ingredient_col]
            measurement = row.get(measurement_col, "1 oz")  # Default to "1 oz" if measurement is missing
            if pd.notna(ingredient):
                if pd.isna(measurement):
                    measurement = "1 oz"  # Assign "1 oz" if the measurement is NaN
                ingredients_dict[ingredient] = measurement
    return ingredients_dict

# Apply the function to each row to create a new column for the ingredient-measurement dictionary
drinks_df['ingredient_dict'] = drinks_df.apply(combine_ingredients_to_dict, axis=1)

# Drop the original ingredient and measurement columns
for i in range(1, 7):
    drinks_df.drop([f'ingredient-{i}', f'measurement-{i}'], axis=1, inplace=True)

# %%
drinks_df
# Out:
#                      name               category  \
# 0                 Gauguin      Cocktail Classics
# 1         Fort Lauderdale      Cocktail Classics
# 2               Apple Pie  Cordials and Liqueurs
# 3    Cuban Cocktail No. 1      Cocktail Classics
# 4             Cool Carlos      Cocktail Classics
# ..                    ...                    ...
# 985  Wallis Blue Cocktail                    Gin
# 986    Minnehaha Cocktail      Cocktail Classics
# 987      Wallick Cocktail                    Gin
# 988   Waikiki Beachcomber                    Gin
# 989        Vow Of Silence                    Gin
#
#                                           instructions                glass  \
# 0    Combine ingredients with a cup of crushed ice ...  Old-Fashioned Glass
# 1    Shake with ice and strain into old-fashioned g...  Old-Fashioned Glass
# 2    Pour into ice-filled old-fashioned glass. Garn...  Old-Fashioned Glass
# 3      Shake with ice and  strain into cocktail glass.       Cocktail Glass
# 4    Mix all ingredients except curacao with ice, s...        Collins Glass
# ..                                                 ...                  ...
# 985  Rim old-fashioned glass with lime and sugar. F...  Old-Fashioned Glass
# 986  Shake well with cracked ice and strain into 4 ...       Cocktail Glass
# 987  Stir with ice and strain into chilled cocktail...       Cocktail Glass
# 988  Shake with ice and strain into chilled cocktai...       Cocktail Glass
# 989  Shake with ice and strain into chilled cocktai...       Cocktail Glass
#
#            glass-size                                              Image  \
# 0       6 to 8 ounces  ......
# 1       6 to 8 ounces  ......
# 2       6 to 8 ounces  ......
# 3    6 or more ounces  ......
# 4     14 to 16 ounces  ......
# ..                ...                                                ...
# 985     6 to 8 ounces  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 986  6 or more ounces  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 987  6 or more ounces  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 988  6 or more ounces  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 989  6 or more ounces  https://encrypted-tbn0.gstatic.com/images?q=tb...
#
#                                        ingredient_dict
# 0    {' Light Rum': '2 oz', ' Passion Fruit Syrup':...
# 1    {' Light Rum': '1 1/2 oz', ' Sweet Vermouth': ...
# 2    {' Apple schnapps': '3 oz', ' Cinnamon schnapp...
# 3    {' Juice of a Lime': '1/2 oz', ' Powdered Suga...
# 4    {' Dark rum': '1 1/2 oz', ' Cranberry Juice': ...
# ..                                                 ...
# 985  {'Lime wedge, superfine sugar': '1', ' Gin': '...
# 986  {' Juice of Orange': '1/4 oz', ' Dry Vermouth'...
# 987  {' Gin': '1 1/2 oz', ' Dry Vermouth': '1 1/2 o...
# 988  {' Gin': '3/4 oz', ' Triple Sec': '3/4 oz', ' ...
# 989  {' Gin': '1 1/2 oz', ' Grapefruit Juice': '3/4...
#
# [990 rows x 7 columns]

# %% [markdown]
# Re checking and removal of missing values if any

# %%
drinks_df.isnull().sum()
# Out:
# name                0
# category            0
# instructions        0
# glass               5
# glass-size         11
# Image               0
# ingredient_dict     0
# dtype: int64

# %% [markdown]
# As glass size is a categorical column we will impute missing columns with Mode of the dataset

# %%
mode_glass_size = drinks_df['glass-size'].mode()[0]  # The mode() method returns a Series, take the first element

# Fill missing values in 'glass-size' with the mode
drinks_df['glass-size'].fillna(mode_glass_size, inplace=True)

# %% [markdown]
# Handling missing values of glass. Checking how many missing values are there. Since most of them are of a Martini. I am imputing it with the Martini Glass.

# %%
missing_glass = drinks_df[drinks_df['glass'].isnull()]

# %%
missing_glass
# Out:
#                        name           category  \
# 53         Martini (Medium)  Cocktail Classics
# 54   Martini (Dry) (5-to-1)  Cocktail Classics
# 255             Dry Martini  Cocktail Classics
# 258      Dillatini Cocktail  Cocktail Classics
# 437           Vodka Martini  Cocktail Classics
#
#                                    instructions glass        glass-size  \
# 53   Follow directions for Martini preparation.   NaN  6 or more ounces
# 54   Follow directions for Martini preparation.   NaN  6 or more ounces
# 255                       serve with an olive.    NaN  6 or more ounces
# 258                    Serve with a dilly bean.   NaN  6 or more ounces
# 437                       serve with an olive.    NaN  6 or more ounces
#
#                                                  Image  \
# 53   ......
# 54   ......
# 255  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 258  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 437  https://encrypted-tbn0.gstatic.com/images?q=tb...
#
#                                        ingredient_dict
# 53   {' Gin': '1 1/2 oz', ' Dry Vermouth': '1/2 oz'...
# 54     {' Gin': '1 2/3 oz', ' Dry Vermouth': '1/3 oz'}
# 255  {' Mr. Boston Gin': '1 2/3 oz', ' Dry Vermouth...
# 258  {' Mr. Boston Gin': '1 1/2 oz', ' Dry Vermouth...
# 437  {' Mr. Boston Vodka': '1 1/2 oz', ' Dry Vermou...

# %%
drinks_df['glass'].fillna('Martini Glass', inplace=True)

# %%
drinks_df.isnull().sum()
# Out:
# name               0
# category           0
# instructions       0
# glass              0
# glass-size         0
# Image              0
# ingredient_dict    0
# dtype: int64

# %%
drinks_df
# Out:
#                      name               category  \
# 0                 Gauguin      Cocktail Classics
# 1         Fort Lauderdale      Cocktail Classics
# 2               Apple Pie  Cordials and Liqueurs
# 3    Cuban Cocktail No. 1      Cocktail Classics
# 4             Cool Carlos      Cocktail Classics
# ..                    ...                    ...
# 985  Wallis Blue Cocktail                    Gin
# 986    Minnehaha Cocktail      Cocktail Classics
# 987      Wallick Cocktail                    Gin
# 988   Waikiki Beachcomber                    Gin
# 989        Vow Of Silence                    Gin
#
#                                           instructions                glass  \
# 0    Combine ingredients with a cup of crushed ice ...  Old-Fashioned Glass
# 1    Shake with ice and strain into old-fashioned g...  Old-Fashioned Glass
# 2    Pour into ice-filled old-fashioned glass. Garn...  Old-Fashioned Glass
# 3      Shake with ice and  strain into cocktail glass.       Cocktail Glass
# 4    Mix all ingredients except curacao with ice, s...        Collins Glass
# ..                                                 ...                  ...
# 985  Rim old-fashioned glass with lime and sugar. F...  Old-Fashioned Glass
# 986  Shake well with cracked ice and strain into 4 ...       Cocktail Glass
# 987  Stir with ice and strain into chilled cocktail...       Cocktail Glass
# 988  Shake with ice and strain into chilled cocktai...       Cocktail Glass
# 989  Shake with ice and strain into chilled cocktai...       Cocktail Glass
#
#            glass-size                                              Image  \
# 0       6 to 8 ounces  ......
# 1       6 to 8 ounces  ......
# 2       6 to 8 ounces  ......
# 3    6 or more ounces  ......
# 4     14 to 16 ounces  ......
# ..                ...                                                ...
# 985     6 to 8 ounces  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 986  6 or more ounces  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 987  6 or more ounces  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 988  6 or more ounces  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 989  6 or more ounces  https://encrypted-tbn0.gstatic.com/images?q=tb...
#
#                                        ingredient_dict
# 0    {' Light Rum': '2 oz', ' Passion Fruit Syrup':...
# 1    {' Light Rum': '1 1/2 oz', ' Sweet Vermouth': ...
# 2    {' Apple schnapps': '3 oz', ' Cinnamon schnapp...
# 3    {' Juice of a Lime': '1/2 oz', ' Powdered Suga...
# 4    {' Dark rum': '1 1/2 oz', ' Cranberry Juice': ...
# ..                                                 ...
# 985  {'Lime wedge, superfine sugar': '1', ' Gin': '...
# 986  {' Juice of Orange': '1/4 oz', ' Dry Vermouth'...
# 987  {' Gin': '1 1/2 oz', ' Dry Vermouth': '1 1/2 o...
# 988  {' Gin': '3/4 oz', ' Triple Sec': '3/4 oz', ' ...
# 989  {' Gin': '1 1/2 oz', ' Grapefruit Juice': '3/4...
#
# [990 rows x 7 columns]

# %% [markdown]
# ### ENCODING FOR MODELING

# %% [markdown]
# I am using Label Encoder for encoding category of cocktails and One Hot Encoder for Glass type. I am not encoding whole dataset because of More encoding can increase the number of Features which can lead to overfitting issue.

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
drinks_df['category'].unique()
# Out:
# array(['Cocktail Classics', 'Cordials and Liqueurs', 'Whiskies', 'Brandy',
#        'Vodka', 'Non-alcoholic Drinks', 'Rum - Daiquiris', 'Rum',
#        'Tequila', 'Shooters', 'Gin'], dtype=object)

# %%
drinks_df['glass'].unique()
# Out:
# array(['Old-Fashioned Glass', 'Cocktail Glass', 'Collins Glass',
#        'Champagne Flute', 'Cordial or Pony Glass', 'Highball Glass',
#        'Irish Coffee Glass', 'Martini Glass', 'Beer Mug', 'Sour Glass',
#        'Brandy Snifter', 'Stem Glass', 'Red-Wine Glass', 'Mug',
#        'Shot Glass', 'Stein', 'Sherry Glass', 'Punch Cup',
#        'Hurricane Glass', 'Pousse-Cafe_ Glass', 'White-Wine Glass'],
#       dtype=object)

# %%
data = {
    'category': ['Cocktail Classics', 'Cordials and Liqueurs', 'Whiskies', 'Brandy',
       'Vodka', 'Non-alcoholic Drinks', 'Rum - Daiquiris', 'Rum',
       'Tequila', 'Shooters', 'Gin'],
    'glass': ['Old-Fashioned Glass', 'Cocktail Glass', 'Collins Glass',
       'Champagne Flute', 'Cordial or Pony Glass', 'Highball Glass',
       'Irish Coffee Glass', 'Martini Glass', 'Beer Mug', 'Sour Glass',
       'Brandy Snifter', 'Stem Glass', 'Red-Wine Glass', 'Mug',
       'Shot Glass', 'Stein', 'Sherry Glass', 'Punch Cup',
       'Hurricane Glass', 'Pousse-Cafe_ Glass', 'White-Wine Glass']
}

# Label Encoding for ordinal categories
label_encoder = LabelEncoder()
drinks_df['category_label'] = label_encoder.fit_transform(drinks_df['category'])

# One-Hot Encoding for nominal categories
one_hot_encoded = pd.get_dummies(drinks_df['glass'], prefix='glass')
drinks_df = pd.concat([drinks_df, one_hot_encoded], axis=1)

# %%
drinks_df
# Out:
#                      name               category  \
# 0                 Gauguin      Cocktail Classics
# 1         Fort Lauderdale      Cocktail Classics
# 2               Apple Pie  Cordials and Liqueurs
# 3    Cuban Cocktail No. 1      Cocktail Classics
# 4             Cool Carlos      Cocktail Classics
# ..                    ...                    ...
# 985  Wallis Blue Cocktail                    Gin
# 986    Minnehaha Cocktail      Cocktail Classics
# 987      Wallick Cocktail                    Gin
# 988   Waikiki Beachcomber                    Gin
# 989        Vow Of Silence                    Gin
#
#                                           instructions                glass  \
# 0    Combine ingredients with a cup of crushed ice ...  Old-Fashioned Glass
# 1    Shake with ice and strain into old-fashioned g...  Old-Fashioned Glass
# 2    Pour into ice-filled old-fashioned glass. Garn...  Old-Fashioned Glass
# 3      Shake with ice and  strain into cocktail glass.       Cocktail Glass
# 4    Mix all ingredients except curacao with ice, s...        Collins Glass
# ..                                                 ...                  ...
# 985  Rim old-fashioned glass with lime and sugar. F...  Old-Fashioned Glass
# 986  Shake well with cracked ice and strain into 4 ...       Cocktail Glass
# 987  Stir with ice and strain into chilled cocktail...       Cocktail Glass
# 988  Shake with ice and strain into chilled cocktai...       Cocktail Glass
# 989  Shake with ice and strain into chilled cocktai...       Cocktail Glass
#
#            glass-size                                              Image  \
# 0       6 to 8 ounces  ......
# 1       6 to 8 ounces  ......
# 2       6 to 8 ounces  ......
# 3    6 or more ounces  ......
# 4     14 to 16 ounces  ......
# ..                ...                                                ...
# 985     6 to 8 ounces  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 986  6 or more ounces  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 987  6 or more ounces  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 988  6 or more ounces  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 989  6 or more ounces  https://encrypted-tbn0.gstatic.com/images?q=tb...
#
#                                        ingredient_dict  category_label  \
# 0    {' Light Rum': '2 oz', ' Passion Fruit Syrup':...               1
# 1    {' Light Rum': '1 1/2 oz', ' Sweet Vermouth': ...               1
# 2    {' Apple schnapps': '3 oz', ' Cinnamon schnapp...               2
# 3    {' Juice of a Lime': '1/2 oz', ' Powdered Suga...               1
# 4    {' Dark rum': '1 1/2 oz', ' Cranberry Juice': ...               1
# ..                                                 ...             ...
# 985  {'Lime wedge, superfine sugar': '1', ' Gin': '...               3
# 986  {' Juice of Orange': '1/4 oz', ' Dry Vermouth'...               1
# 987  {' Gin': '1 1/2 oz', ' Dry Vermouth': '1 1/2 o...               3
# 988  {' Gin': '3/4 oz', ' Triple Sec': '3/4 oz', ' ...               3
# 989  {' Gin': '1 1/2 oz', ' Grapefruit Juice': '3/4...               3
#
#      glass_Beer Mug  glass_Brandy Snifter  ...  glass_Old-Fashioned Glass  \
# 0             False                 False  ...                       True
# 1             False                 False  ...                       True
# 2             False                 False  ...                       True
# 3             False                 False  ...                      False
# 4             False                 False  ...                      False
# ..              ...                   ...  ...                        ...
# 985           False                 False  ...                       True
# 986           False                 False  ...                      False
# 987           False                 False  ...                      False
# 988           False                 False  ...                      False
# 989           False                 False  ...                      False
#
#      glass_Pousse-Cafe_ Glass  glass_Punch Cup  glass_Red-Wine Glass  \
# 0                       False            False                 False
# 1                       False            False                 False
# 2                       False            False                 False
# 3                       False            False                 False
# 4                       False            False                 False
# ..                        ...              ...                   ...
# 985                     False            False                 False
# 986                     False            False                 False
# 987                     False            False                 False
# 988                     False            False                 False
# 989                     False            False                 False
#
#      glass_Sherry Glass  glass_Shot Glass  glass_Sour Glass  glass_Stein  \
# 0                 False             False             False        False
# 1                 False             False             False        False
# 2                 False             False             False        False
# 3                 False             False             False        False
# 4                 False             False             False        False
# ..                  ...               ...               ...          ...
# 985               False             False             False        False
# 986               False             False             False        False
# 987               False             False             False        False
# 988               False             False             False        False
# 989               False             False             False        False
#
#      glass_Stem Glass  glass_White-Wine Glass
# 0               False                   False
# 1               False                   False
# 2               False                   False
# 3               False                   False
# 4               False                   False
# ..                ...                     ...
# 985             False                   False
# 986             False                   False
# 987             False                   False
# 988             False                   False
# 989             False                   False
#
# [990 rows x 29 columns]

# %% [markdown]
# Converting the ingredients dictionary to string because of ease in modelling. I am also vectorizing all ingredients to recommend similarity based recommendations.

# %%
def dict_to_string(ingredient_dict):
    return " ".join([f"{key}:{value}" for key, value in ingredient_dict.items()])

def dict_to_string(ingredient_dict):
    return " ".join([f"{key}:{value}" for key, value in ingredient_dict.items()])

# Apply the function to create a new text column
drinks_df['ingredients_text'] = drinks_df['ingredient_dict'].apply(dict_to_string)

# Use the 'ingredients_text' column for vectorization
vectorizer_ingredients = TfidfVectorizer(stop_words='english')
vectorized_ingredients = vectorizer_ingredients.fit_transform(drinks_df['ingredients_text']).toarray()

# Check the shape of the vectorized ingredients
print(f"Shape of vectorized ingredients: {vectorized_ingredients.shape}")
# Out:
# Shape of vectorized ingredients: (990, 458)

# %% [markdown]
# Combining the Encoded features One hot, Label Encoded Features  and Vectorized Ingredients

# %%
encoded_features = np.hstack([
    drinks_df[['category_label']].values,  # Label-encoded category
    drinks_df.filter(like='glass_').values,  # One-hot encoded glass
    vectorized_ingredients  # TF-IDF vectorized ingredients
])

# %% [markdown]
# # MODELING

# %% [markdown]
# ### Data Preprocessing and Scaling

# %% [markdown]
# I am using Standard Scaler for feature normalization and scaling encoded features.

# %%
scaler = StandardScaler()
normalized_features = scaler.fit_transform(encoded_features)

# %%
X = normalized_features

# %% [markdown]
# Splitting the data into training and testing, where 80% is training and 20% is testing data.

# %%
X_train, X_test, indices_train, indices_test = train_test_split(
    X, drinks_df.index, test_size=0.2, random_state=42
)

# %% [markdown]
# Applying PCA for dimensionality reduction because after encoding the number features become very high (Curse of Dimensionality) leading to overfitting. So to prevent this we do PCA and reduce the dimensionality of the data.

# %%
# Fit PCA on the training data
pca = PCA(n_components=10)  # Specify the number of components to retain
pca.fit(X_train)

# Transform the training and test data
X_reduced_train = pca.transform(X_train)
X_reduced_test = pca.transform(X_test)

print(X_reduced_train.shape)  # Should be (792, 10)
print(X_reduced_test.shape)
# Out:
# (792, 10)
# (198, 10)

# %% [markdown]
# ### Building the Modelling

# %% [markdown]
# ### Neural Network

# %% [markdown]
# A computational model inspired by the human brain. It consists of layers of interconnected nodes (neurons) designed to recognize patterns in data.
#
# **Key Components of a Neural Network:**
#
# - Input Layer: Takes the raw input data.
# - Hidden Layer: Performs Computations and extract patterns,
# - Output Layer: Produces te final Output based on the problem.
# - Activation Function: Non-Linear Functions that allow network to learn Complex Relationships.

# %%
model = Sequential([
    Dense(256, activation='relu', kernel_regularizer=l2(0.01),input_shape=(10,)),
    Dropout(0.4),
    BatchNormalization(),
    Dense(128, activation='relu', kernel_regularizer=l2(0.01),input_shape=(10,)),
    Dropout(0.3),
    Dense(64, activation='relu', kernel_regularizer=l2(0.01),input_shape=(10,)),
    Dropout(0.2),
    Dense(32, activation='relu', kernel_regularizer=l2(0.01),input_shape=(10,)),
    Dropout(0.1),
    BatchNormalization(),
    Dense(10, activation='sigmoid')
])

# %% [markdown]
# Training the model over the training data and used early stopping from preventing loss and time.

# %%
early_stopping = EarlyStopping(
    monitor='val_loss',  # Monitor validation loss
    patience=10,         # Stop if no improvement after 10 epochs
    restore_best_weights=True  # Restore model weights from the epoch with the best loss
)

# %%
model.compile(optimizer=Adam(learning_rate=0.005), loss='mse', metrics=['mae'])
model_nn = model.fit(
    X_reduced_train, X_reduced_train,  # Autoencoder: input equals output
    validation_split=0.2,
    epochs=100,
    batch_size=50,
    callbacks=[early_stopping]
)
reconstruction_loss = model.evaluate( X_reduced_test,X_reduced_test)
print(f"Reconstruction Loss on Test Data: {reconstruction_loss}")
# Out:
# Epoch 1/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 7.9075 - mae: 0.8623 - val_loss: 8.3769 - val_mae: 0.9617
# Epoch 2/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.1786 - mae: 0.8018 - val_loss: 7.6452 - val_mae: 0.9320
# Epoch 3/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.7214 - mae: 0.7398 - val_loss: 7.2140 - val_mae: 0.9055
# Epoch 4/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.3782 - mae: 0.7895 - val_loss: 6.9521 - val_mae: 0.8821
# Epoch 5/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.1991 - mae: 0.7017 - val_loss: 6.8129 - val_mae: 0.8803
# Epoch 6/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.5385 - mae: 0.6875 - val_loss: 6.7669 - val_mae: 0.8707
# Epoch 7/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.7807 - mae: 0.6654 - val_loss: 6.7119 - val_mae: 0.8608
# Epoch 8/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.4530 - mae: 0.6115 - val_loss: 6.6458 - val_mae: 0.8590
# Epoch 9/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.9328 - mae: 0.6318 - val_loss: 6.5971 - val_mae: 0.8614
# Epoch 10/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.9603 - mae: 0.6968 - val_loss: 6.5873 - val_mae: 0.8434
# Epoch 11/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.3335 - mae: 0.6191 - val_loss: 6.5445 - val_mae: 0.8496
# Epoch 12/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.4628 - mae: 0.6887 - val_loss: 6.5739 - val_mae: 0.8584
# Epoch 13/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.3715 - mae: 0.6353 - val_loss: 6.5422 - val_mae: 0.8381
# Epoch 14/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.6851 - mae: 0.7435 - val_loss: 6.5266 - val_mae: 0.8272
# Epoch 15/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.8702 - mae: 0.6601 - val_loss: 6.4901 - val_mae: 0.8201
# Epoch 16/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.2721 - mae: 0.6643 - val_loss: 6.4851 - val_mae: 0.8163
# Epoch 17/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5118 - mae: 0.6557 - val_loss: 6.4883 - val_mae: 0.8172
# Epoch 18/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.7948 - mae: 0.6994 - val_loss: 6.4886 - val_mae: 0.8232
# Epoch 19/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.7884 - mae: 0.7163 - val_loss: 6.5312 - val_mae: 0.8341
# Epoch 20/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.3114 - mae: 0.6525 - val_loss: 6.5641 - val_mae: 0.8263
# Epoch 21/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5424 - mae: 0.6793 - val_loss: 6.5364 - val_mae: 0.8303
# Epoch 22/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.0372 - mae: 0.6856 - val_loss: 6.5075 - val_mae: 0.8271
# Epoch 23/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5161 - mae: 0.5902 - val_loss: 6.4663 - val_mae: 0.8199
# Epoch 24/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.7628 - mae: 0.6735 - val_loss: 6.4526 - val_mae: 0.8376
# Epoch 25/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6804 - mae: 0.5903 - val_loss: 6.4355 - val_mae: 0.8275
# Epoch 26/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.0364 - mae: 0.7867 - val_loss: 6.4717 - val_mae: 0.7955
# Epoch 27/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9704 - mae: 0.6121 - val_loss: 6.4720 - val_mae: 0.7885
# Epoch 28/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.4148 - mae: 0.6450 - val_loss: 6.4456 - val_mae: 0.7884
# Epoch 29/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.1095 - mae: 0.6142 - val_loss: 6.3961 - val_mae: 0.7972
# Epoch 30/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2513 - mae: 0.6215 - val_loss: 6.3934 - val_mae: 0.8020
# Epoch 31/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.5487 - mae: 0.6124 - val_loss: 6.3748 - val_mae: 0.8056
# Epoch 32/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.7738 - mae: 0.6494 - val_loss: 6.3929 - val_mae: 0.8060
# Epoch 33/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.6277 - mae: 0.6718 - val_loss: 6.3805 - val_mae: 0.8109
# Epoch 34/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.9083 - mae: 0.6788 - val_loss: 6.3979 - val_mae: 0.8083
# Epoch 35/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.8556 - mae: 0.6910 - val_loss: 6.4148 - val_mae: 0.8256
# Epoch 36/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.0242 - mae: 0.6150 - val_loss: 6.3831 - val_mae: 0.7997
# Epoch 37/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.0908 - mae: 0.6800 - val_loss: 6.4118 - val_mae: 0.7820
# Epoch 38/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.3480 - mae: 0.7664 - val_loss: 6.4224 - val_mae: 0.7864
# Epoch 39/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.1137 - mae: 0.6582 - val_loss: 6.3806 - val_mae: 0.7935
# Epoch 40/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4575 - mae: 0.6154 - val_loss: 6.3518 - val_mae: 0.7739
# Epoch 41/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.0289 - mae: 0.6702 - val_loss: 6.4477 - val_mae: 0.7879
# Epoch 42/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.0697 - mae: 0.7322 - val_loss: 6.3488 - val_mae: 0.7783
# Epoch 43/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.8759 - mae: 0.6465 - val_loss: 6.3272 - val_mae: 0.7784
# Epoch 44/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6521 - mae: 0.6386 - val_loss: 6.3201 - val_mae: 0.7796
# Epoch 45/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9844 - mae: 0.6244 - val_loss: 6.3896 - val_mae: 0.8190
# Epoch 46/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.5744 - mae: 0.6512 - val_loss: 6.3734 - val_mae: 0.7664
# Epoch 47/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.1450 - mae: 0.6875 - val_loss: 6.3239 - val_mae: 0.7559
# Epoch 48/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0695 - mae: 0.6282 - val_loss: 6.3357 - val_mae: 0.7658
# Epoch 49/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.1871 - mae: 0.6322 - val_loss: 6.4059 - val_mae: 0.7793
# Epoch 50/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7750 - mae: 0.6604 - val_loss: 6.3898 - val_mae: 0.7440
# Epoch 51/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.7038 - mae: 0.6858 - val_loss: 6.4568 - val_mae: 0.7461
# Epoch 52/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.0622 - mae: 0.6509 - val_loss: 6.4413 - val_mae: 0.7439
# Epoch 53/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6844 - mae: 0.5773 - val_loss: 6.4728 - val_mae: 0.7457
# Epoch 54/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.9022 - mae: 0.6815 - val_loss: 6.4616 - val_mae: 0.7550
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9189 - mae: 0.5062
# Reconstruction Loss on Test Data: [0.8265889286994934, 0.4890286326408386]

# %% [markdown]
# Plotting a graph of Training vs validation loss and plotting optimal epoch where the loss is lowest.

# %%
def find_optimal_epoch(history):
    """
    Find the epoch with the lowest validation loss
    """
    val_losses = history.history['val_loss']
    optimal_epoch = np.argmin(val_losses)
    return optimal_epoch, val_losses[optimal_epoch]

optimal_epoch, optimal_loss = find_optimal_epoch(model_nn)

# %%
from tensorflow.keras.losses import MeanSquaredError

# Compile the model with full loss function reference
model.compile(optimizer=Adam(learning_rate=0.005), loss=MeanSquaredError(), metrics=['mae'])

# Save the model
model.save("beverage_recommendation_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import pickle

# Save the processed DataFrame to a .pkl file
with open("drinks_df.pkl", "wb") as file:
    pickle.dump(drinks_df, file)

# %%
feature_matrix = np.vstack([X_reduced_train, X_reduced_test])  # Combine training and test data
np.save("feature_matrix.npy", feature_matrix)

# %%
plt.figure(figsize=(12, 6))
plt.plot(model_nn.history['loss'], label='Training Loss', marker='o')
plt.plot(model_nn.history['val_loss'], label='Validation Loss', marker='x')

# Find the optimal epoch
val_losses = model_nn.history['val_loss']
optimal_epoch = np.argmin(val_losses)
optimal_loss = val_losses[optimal_epoch]

# Add a vertical dotted line at the optimal point
plt.axvline(x=optimal_epoch, color='r', linestyle=':', label='Optimal Epoch')

# Highlight the optimal point
plt.scatter(
    optimal_epoch, 
    optimal_loss, 
    color='red', 
    s=200, 
    label='Optimal Point', 
    marker='*'
)

plt.title("Model Loss Over Epochs with Optimal Point")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(alpha=0.7)
plt.annotate(
    f'Optimal Epoch: {optimal_epoch}\nLoss: {optimal_loss:.4f}', 
    xy=(optimal_epoch, optimal_loss),
    xytext=(10, 30),
    textcoords='offset points',
    arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=0.2')
)
plt.show()

# %%
feature_matrix = np.vstack([X_reduced_train, X_reduced_test])

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns

def plot_beverage_similarity(feature_matrix, drinks_df, drink_index, model, top_n=10):
    """
    Plot the similarity of beverages and highlight recommendations.
    
    :param feature_matrix: Processed feature matrix
    :param drinks_df: Original DataFrame with drink details
    :param drink_index: Index of the selected drink
    :param model: Trained Keras model
    :param top_n: Number of similar beverages to highlight
    """
    # Predict similarities
    similarities = model.predict(feature_matrix)
    drink_similarities = similarities[drink_index]

    # Get indices of the top similar drinks
    top_indices = np.argsort(-drink_similarities)[1:top_n + 1]
    top_drinks = drinks_df.iloc[top_indices]

    # Reduce dimensions for visualization using t-SNE
    tsne = TSNE(n_components=2, random_state=42)
    reduced_features = tsne.fit_transform(feature_matrix)

    # Plot the beverages in a 2D space
    plt.figure(figsize=(12, 8))
    sns.scatterplot(
        x=reduced_features[:, 0],
        y=reduced_features[:, 1],
        hue=drinks_df['category'],  # Color by category
        palette='Set2',
        alpha=0.6
    )
    
    # Highlight the selected drink and its recommendations
    plt.scatter(
        reduced_features[drink_index, 0], 
        reduced_features[drink_index, 1], 
        color='red', 
        label='Selected Drink', 
        edgecolor='black', 
        s=200
    )
    plt.scatter(
        reduced_features[top_indices, 0], 
        reduced_features[top_indices, 1], 
        color='blue', 
        label='Recommended Drinks', 
        edgecolor='black', 
        s=100
    )
    
    # Annotate drink names for recommendations
    for idx in top_indices:
        plt.text(
            reduced_features[idx, 0], 
            reduced_features[idx, 1], 
            drinks_df.iloc[idx]['name'], 
            fontsize=9, 
            ha='right'
        )
    
    # Customize the plot
    plt.title("Beverage Similarity and Recommendations", fontsize=16)
    plt.xlabel("t-SNE Dimension 1", fontsize=12)
    plt.ylabel("t-SNE Dimension 2", fontsize=12)
    plt.legend(loc='upper right', fontsize=10)
    plt.grid(alpha=0.3)
    plt.tight_layout()
    plt.show()

# Example usage: Plot similarity and recommendations for the 10th drink
plot_beverage_similarity(feature_matrix, drinks_df, drink_index=10, model=model, top_n=10)
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
def plot_accuracy_graph(history):
    """
    Plots the Mean Absolute Error (MAE) over epochs for training and validation sets.

    :param history: History object from Keras model training.
    """
    plt.figure(figsize=(12, 6))
    
    # Plot training and validation MAE
    plt.plot(history.history['mae'], label='Training MAE', marker='o')
    plt.plot(history.history['val_mae'], label='Validation MAE', marker='x')
    
    # Add titles and labels
    plt.title("Model Accuracy (MAE) Over Epochs", fontsize=16)
    plt.xlabel("Epochs", fontsize=12)
    plt.ylabel("Mean Absolute Error (MAE)", fontsize=12)
    
    # Add legend and grid
    plt.legend(fontsize=12)
    plt.grid(alpha=0.5)
    
    # Display the plot
    plt.tight_layout()
    plt.show()

# Plot MAE graph using the model's training history
plot_accuracy_graph(model_nn)

# %%
def plot_training_validation_testing_accuracy(history, test_mae):
    """
    Plots the MAE for training, validation over epochs, and testing.

    :param history: History object from Keras model training.
    :param test_mae: MAE on the test dataset.
    """
    plt.figure(figsize=(12, 6))
    
    # Plot training and validation MAE
    plt.plot(history.history['mae'], label='Training MAE', marker='o')
    plt.plot(history.history['val_mae'], label='Validation MAE', marker='x')
    
    # Add the test MAE as a single point
    plt.scatter(len(history.history['mae']), test_mae, color='red', label='Test MAE', s=150, edgecolor='black')
    
    # Customize plot
    plt.title("Training, Validation, and Testing Accuracy (MAE)", fontsize=16)
    plt.xlabel("Epochs", fontsize=12)
    plt.ylabel("Mean Absolute Error (MAE)", fontsize=12)
    plt.legend(fontsize=12)
    plt.grid(alpha=0.5)
    
    # Annotate the testing MAE
    plt.annotate(
        f"Test MAE: {test_mae:.4f}",
        xy=(len(history.history['mae']), test_mae),
        xytext=(-50, 20),
        textcoords='offset points',
        arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=0.3'),
        fontsize=12
    )
    
    plt.tight_layout()
    plt.show()

# Get the test MAE from the evaluation
test_loss, test_mae = model.evaluate(X_reduced_test, X_reduced_test, verbose=0)

# Plot the graph
plot_training_validation_testing_accuracy(model_nn, test_mae)

# %% [markdown]
# Creating a function of recommendations and receiving recommendations from the model.

# %%
import numpy as np
import json

def recommend_drinks(drink_index, model, drinks_df, feature_matrix, top_n=5, variability=0.1):
    # Predict similarities
    similarities = model.predict(feature_matrix)
    drink_similarities = similarities[drink_index]
    
    # Calculate the number of top results to consider for random sampling
    n_samples = int(len(drink_similarities) * variability)
    
    # Ensure that we do not exceed the number of available indices
    n_samples = max(n_samples, top_n)  # Make sure we have at least 'top_n' samples

    # Get indices of the top similar drinks (excluding the drink itself)
    top_indices = np.argsort(-drink_similarities)[1:n_samples + 1]
    
    # If fewer indices than requested, adjust the number of recommendations
    final_top_n = min(top_n, len(top_indices))
    
    # Randomly pick from the top indices
    random_indices = np.random.choice(top_indices, size=final_top_n, replace=False)
    
    # Fetch details for recommended drinks
    recommended_drinks = drinks_df.iloc[random_indices]
    recommendations = []
    
    for _, drink in recommended_drinks.iterrows():
        drink_details = {
            "name": drink.get("name"),
            "category": drink.get("category"),
            "ingredients": drink.get("ingredient_dict"),
            "glass": drink.get("glass"),
            "instructions": drink.get("instructions"),
            "image": drink.get("Image")
        }
        recommendations.append(drink_details)
    
    # Convert to JSON
    return json.dumps(recommendations, indent=4)

# Example Usage: Get recommendations for the first drink
drink_index = 10
recommendation_json = recommend_drinks(drink_index, model, drinks_df, feature_matrix, top_n=10)

# Print JSON result
print("Recommendations in JSON Format:")
print(recommendation_json)
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Recommendations in JSON Format:
# [
#     {
#         "name": "Cherry Rum",
#         "category": "Cocktail Classics",
#         "ingredients": {
#             " Light Rum": "1 1/4 oz",
#             " cherry-flavored brandy": "1 1/2 oz",
#             " Light cream": "1 oz"
#         },
#         "glass": "Cocktail Glass",
#         "instructions": "Shake with ice and strain into cocktail glass.",
#         "image": "data:image/jpeg;base64,..."
#     },
#     {
#         "name": "John Collins",
#         "category": "Whiskies",
#         "ingredients": {
#             " Bourbon whiskey": "2 oz",
#             " Fresh lemon juice": "1 oz",
#             " Simple Syrup": "1/2 oz",
#             " Soda water": "1 oz",
#             " Orange and lemon wheels, maraschino cherry": "1 oz"
#         },
#         "glass": "Collins Glass",
#         "instructions": "Shake first three ingredients with ice and strain into Collins glass. Add ice, fill with soda water, and stir. Garnish with orange, lemon, and cherry. Serve with straws.",
#         "image": "data:image/jpeg;base64,..."
#     },
#     {
#         "name": "Casa Blanca",
#         "category": "Cocktail Classics",
#         "ingredients": {
#             " Light Rum": "2 oz",
#             " Lime Juice": "1 1/2 oz",
#             " Triple Sec": "1 1/2 oz",
#             " Maraschino": "1 1/2 oz"
#         },
#         "glass": "Cocktail Glass",
#         "instructions": "Shake with ice and strain into cocktail glass.",
#         "image": "data:image/jpeg;base64,..."
#     },
#     {
#         "name": "Cool Carlos",
#         "category": "Cocktail Classics",
#         "ingredients": {
#             " Dark rum": "1 1/2 oz",
#             " Cranberry Juice": "2 oz",
#             " Pineapple Juice": "2 oz",
#             " Orange curacao": "1 oz",
#             " Sour Mix": "1 oz"
#         },
#         "glass": "Collins Glass",
#         "instructions": "Mix all ingredients except curacao with ice, shake well. Pour into collins glass and float curacao on top. Garnish with pineapple and orange slices, and a cherry.",
#         "image": "data:image/jpeg;base64,..."
#     },
#     {
#         "name": "Gauguin",
#         "category": "Cocktail Classics",
#         "ingredients": {
#             " Light Rum": "2 oz",
#             " Passion Fruit Syrup": "1 oz",
#             " Lemon Juice": "1 oz",
#             " Lime Juice": "1 oz"
#         },
#         "glass": "Old-Fashioned Glass",
#         "instructions": "Combine ingredients with a cup of crushed ice in blender and blend at low speed. Serve in old-fashioned glass. Top with a cherry.",
#         "image": "data:image/jpeg;base64,..."
#     },
#     {
#         "name": "Fort Lauderdale",
#         "category": "Cocktail Classics",
#         "ingredients": {
#             " Light Rum": "1 1/2 oz",
#             " Sweet Vermouth": "1/2 oz",
#             " Juice of Orange": "1/4 oz",
#             " Juice of a Lime": "1/4 oz"
#         },
#         "glass": "Old-Fashioned Glass",
#         "instructions": "Shake with ice and strain into old-fashioned glass over ice cubes. Add a slice of orange.",
#         "image": "data:image/jpeg;base64,..."
#     },
#     {
#         "name": "Apple Pie",
#         "category": "Cordials and Liqueurs",
#         "ingredients": {
#             " Apple schnapps": "3 oz",
#             " Cinnamon schnapps": "1 oz",
#             " Apple slice": "1 oz"
#         },
#         "glass": "Old-Fashioned Glass",
#         "instructions": "Pour into ice-filled old-fashioned glass. Garnish with apple and top with cinnamon.",
#         "image": "data:image/jpeg;base64,..."
#     },
#     {
#         "name": "Amber Amour",
#         "category": "Cordials and Liqueurs",
#         "ingredients": {
#             " Amaretto": "1 1/2 oz",
#             " Fresh lemon juice": "1/4 oz",
#             " Simple Syrup": "1/4 oz",
#             " Soda water": "1 oz"
#         },
#         "glass": "Collins Glass",
#         "instructions": "Pour amaretto, lemon juice, and syrup into ice-filled Collins glass. Top with soda water and stir. Garnish with cherry.",
#         "image": "data:image/jpeg;base64,..."
#     },
#     {
#         "name": "Caribbean Champagne",
#         "category": "Cocktail Classics",
#         "ingredients": {
#             " Light Rum": "1/2 oz",
#             " Creme de banana": "1/2 oz",
#             "Chilled Champagne": " "
#         },
#         "glass": "Champagne Flute",
#         "instructions": "Pour rum and banana liqueur into champagne flute. Fill with champagne and stir lightly. Add a slice of banana.",
#         "image": "data:image/jpeg;base64,..."
#     }
# ]
